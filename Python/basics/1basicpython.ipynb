# %%
print('Assalamalaikum')
# Out:
# Assalamalaikum

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # main
# ## sub
# - points
#
#  1 # means main
#
#  2 ## means sub heading
#
#  3 - means points

# %%
2+2
# Out:
# 4

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
10 * 'Mazhar '
# Out:
# 'Mazhar Mazhar Mazhar Mazhar Mazhar Mazhar Mazhar Mazhar Mazhar Mazhar '

# %% [markdown]
# # Data Types

# %%
type(10)
# Out:
# int

# %%
type('Hello')
# Out:
# str

# %%
'Hello' + 'World'
# Out:
# 'HelloWorld'

# %%
type("mazhar 123")
# Out:
# str

# %% [markdown]
# ### Variable Assignment
#
# #Syntax
#
# #variable_name = value
#
# a =10
#
# b= 20
#
# c =a+b

# %%
a =10

b= 20

c =a+b

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
## Mathematical Operations will be performed
print(a+b)
print(a-b)
print(a/b)
print(a%b)
print(a**b)
# Out:
# 30
# -10
# 0.5
# 10
# 100000000000000000000

# %%
print('Hello')
print(type('Hello'))
# Out:
# Hello
# <class 'str'>

# %%
first_name = 'Mazhar'
last_name = 'Mohammed'

# %%
print('My first name is {} and last name is {}'.format(first_name,last_name))
print('My first name is {} and last name is {}'.format(last_name,first_name))
# Out:
# My first name is Mazhar and last name is Mohammed
# My first name is Mohammed and last name is Mazhar

# %%
print('My first name is {last_name} and last name is {first_name}'.format(first_name =first_name ,last_name=last_name))
print('My first name is {first_name} and last name is {last_name}'.format(first_name =last_name ,last_name=first_name))
print('My first name is {first_name} and last name is {first_name}'.format(first_name =first_name ,last_name=last_name))
# Out:
# My first name is Mohammed and last name is Mazhar
# My first name is Mohammed and last name is Mazhar
# My first name is Mazhar and last name is Mazhar

# %%
print('My first name is {last} and last name is {first}'.format(first =first_name ,last=last_name))
# Out:
# My first name is Mohammed and last name is Mazhar
